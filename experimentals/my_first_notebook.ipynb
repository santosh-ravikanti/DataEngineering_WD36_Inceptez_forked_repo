# %% [markdown]
# ![](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
CREATE CONNECTION mysql_conn
TYPE JDBC
OPTIONS (
  url 'jdbc:mysql://136.114.39.161:3306/cc_mart',
  user 'devuser',
  password 'Inceptez@123',
  driver 'com.mysql.cj.jdbc.Driver'
);

# %%
# %pip install mysql-connector-python

# %%
jdbc_url = "jdbc:mysql://136.114.39.161:3306/cc_mart"

connection_props = {
    "user": "devuser",
    "password": "Inceptez@123",
    "driver": "com.mysql.cj.jdbc.Driver"
}

df = spark.read.jdbc(
    url=jdbc_url,
    table="orders",
    properties=connection_props
)

df.display()

# %%
# %sql
CREATE CONNECTION mysql_connection
TYPE mysql
OPTIONS (
  host '152.58.71.34.bc.googleusercontent.com',
  port '3306',
  user 'root',
  password 'Inceptez@123',
  database 'mysql'
);

# %%
# %sql
CREATE CONNECTION mysql_connectionworking
TYPE mysql
OPTIONS (
  host '152.58.71.34.bc.googleusercontent.com',
  port '3306',
  user 'root',
  password 'Inceptez@123',
  database 'mysql'
);

# %%
spark.sql("select * from foreigncat.testdb.tbl1").show()
